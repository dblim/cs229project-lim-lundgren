# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn
import glob, os  
import matplotlib.ticker as mticker

# %%
# Code taken from https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe

path = 'random_samples'                  # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))    
list = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

    
df = pd.concat(list, axis=0, ignore_index=False)

print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Number of LSTM units  Lookback period  Learning rate  Average MSE
# 0                    11               19         0.0500     0.000004
# 1                    35               10         0.5000     0.000133
# 0                     4               22         0.0010     0.000003
# 1                     8               25         0.0010     0.000003
# 0                    26               11         0.0005     0.000003
# 1                    23               26         0.0010     0.000003
# 0                    15               27         0.0005     0.000003
# 1                    28               40         0.1000     0.000013
# 0                    40               13         0.1000     0.000063
# 1                    22               16         0.0001     0.000019

# %%
LSTM_units =df['Number of LSTM units'].values
lookback = df['Lookback period'].values
learning_rate = df['Learning rate'].values
Avg_MSE = df['Average MSE'].values
print(Avg_MSE)
# Out:
# [4.10409191e-06 1.32712883e-04 3.44072437e-06 3.44734516e-06
#  3.43340066e-06 3.44087494e-06 3.43456631e-06 1.31389430e-05
#  6.34725581e-05 1.94747978e-05]

# %%
print(LSTM_units)
# Out:
# [11 35  4  8 26 23 15 28 40 22]

# %%
jet=plt.get_cmap('tab20b')

# %%
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111, projection='3d')
xs = LSTM_units
ys = lookback
zs = -np.log(learning_rate)
c = -np.log(Avg_MSE)

print(xs)
print(ys)
print(zs)
print(c)
p = ax.scatter(xs,ys,zs, c=c, cmap=jet)


ax.set_xlabel('LSTM units')
ax.set_ylabel('Lookback period')
ax.set_zlabel('Learning rate')

plt.title('Hyperparameters  vs. MSE (50 epochs)')
fig.colorbar(p)


seaborn.set()
plt.show()
# Out:
# [11 35  4  8 26 23 15 28 40 22]
# [19 10 22 25 11 26 27 40 13 16]
# [2.99573227 0.69314718 6.90775528 6.90775528 7.60090246 6.90775528
#  7.60090246 2.30258509 2.30258509 9.21034037]
# [12.40352605  8.92732254 12.57982854 12.57790614 12.58195934 12.57978478
#  12.5816199  11.23992999  9.6649029  10.84638935]

# %%
plt.scatter(ys, zs)

# %%
plt.scatter(xs,ys)
